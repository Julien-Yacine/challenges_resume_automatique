# %%
import wikipedia
import requests
from bs4 import BeautifulSoup
import time
import numpy as np

# %%
import requests
from bs4 import BeautifulSoup
 
html = requests.get('https://fr.wikipedia.org/w/index.php?title=Cat%C3%A9gorie:Portail:%C3%89conomie/Articles_li%C3%A9s&from=B').content

html=html.decode('utf-8')
soup = BeautifulSoup(html, "lxml")

# %%
html
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs" lang="fr" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>Catégorie:Portail:Économie/Articles liés — Wikipédia</title>\n<script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":!1,"wgSeparatorTransformTable":[",\\t.","\xa0\\t,"],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","janvier","février","mars","avril","mai","juin","juillet","août","septembre","octobre","novembre","décembre"],"wgMonthNamesShort":["","janv.","fév.","mars","avr.","mai","juin","juill.","août","sept.","oct.","nov.","déc."],"wgRequestId":"XcpYagpAAD8AAEVnfhgAAAEH","wgCSPNonce":!1,"wgCanonicalNamespace":"Category","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":14,"wgPageName":"Catégorie:Portail:Économie/Articles_liés","wgTitle":"Portail:Économie/Articles liés","wgCurRevisionId":92763934,"wgRevisionId":92763934,"wgArticleId":3359163,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGr
# ...

# %%
toto = ">page suivante</a>)<div lang=fr" 
regex = r'page suivante(.*?)$'
html2 = re.findall( regex, html)
#type(toto)
html2
# Out:
# []

# %%
links = []
for i in soup.find_all(name = 'li'):
    #print(i)
    for link in i.find_all('title'):
        print(i)
        links.append(link)
print(links)
# Out:
# []

# %%
title = soup.find('a','title')

# %%
title

# %%
import re
toto = []
#for i in links: 
    #print(i)
#    article=re.findall( '/wiki/.*$', i)
#    if article!=[]:
#        #print(article[0])
#        article = 'https://fr.wikipedia.org' + article[0]
#        toto.append(article)
for i in links: 
    #print(i)
    article=re.findall( '/wiki/(.*?)$', i)
    if article!=[]:
        #print(article[0])
        #article = 'https://fr.wikipedia.org' + article[0]
        toto.append(article)
toto
# Out:
# [['Cat%C3%A9gorie:%C3%89conomie'],
#  ['Portail:%C3%89conomie'],
#  ['Projet:%C3%89conomie'],
#  ['Discussion_Projet:%C3%89conomie'],
#  ['Cat%C3%A9gorie:Portail:%C3%89conomie/Articles_li%C3%A9s'],
#  ['Sp%C3%A9cial:ArbreCat%C3%A9gorie/Portail:%C3%89conomie/Articles_li%C3%A9s'],
#  ['Sp%C3%A9cial:Recherche/incategory:%22Portail:%C3%89conomie/Articles_li%C3%A9s%22'],
#  ['Sp%C3%A9cial:Suivi_des_liens/Cat%C3%A9gorie:Portail:%C3%89conomie/Articles_li%C3%A9s'],
#  ['B-Park'],
#  ['B._Braun'],
#  ['B/E_Aerospace'],
#  ['B%26B_Hotels'],
#  ['B%26H_Airlines'],
#  ['B%26M_(distribution)'],
#  ['B%26Q'],
#  ['B%26R'],
#  ['B2B_Banque'],
#  ['B2S'],
#  ['B2W'],
#  ['B10_life'],
#  ['B92'],
#  ['BA_CityFlyer'],
#  ['Babacar_Ba'],
#  ['Fatoumata_B%C3%A2'],
#  ['Sangar%C3%A9_Niamoto_Ba'],
#  ['Daniel_Baal'],
#  ['Barbara_Baarsma'],
#  ['Naoum_Baba%C3%AFev'],
#  ['Babani'],
#  ['Pierre_Babaud_de_la_Chaussade'],
#  ['Isaac_Babbitt'],
#  ['Babcock_%26_Brown'],
#  ['Babcock_%26_Wilcox'],
# ...

# %%
film_links = []
for decade in toto[15:16]:
        print(f'Collecting films from {decade}')
        html = requests.get(decade)
        b = BeautifulSoup(html.text, 'lxml')
        print(b)
# Out:
# ...
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="fr">
# <head>
# <meta charset="utf-8"/>
# <title>B&amp;R — Wikipédia</title>
# ...

# %%
import wikipedia
wikipedia.set_lang("fr")
for i in toto[20:22]:
    print("Resume de l article : ")
    print(i)
    print(wikipedia.summary(i))
# Out:
# Resume de l article :
# ['B92']
# B92 (en serbe cyrillique : Б92) est une station de radio et une chaîne de télévision situées à Belgrade, la capitale de la Serbie. Elle vise en priorité un public jeune et citadin. Sur le plan politique, elle peut se définir comme libérale. B92 est dirigée par Veran Matić, un des patrons de média les plus respectés des Balkans.
# B92 fut un des rares médias à diffuser des informations indépendantes à l'époque de Slobodan Milošević et elle a appuyé les mouvements de contestation qui se sont développés à Belgrade dans les années 1990. Pour cette raison, B92 a obtenu la récompense MTV Free your Mind en 1998, ainsi que d'autres récompenses dans le domaine du journalisme et des droits de l'homme.
# Resume de l article :
# ['BA_CityFlyer']
# ...

# %%
import wikipedia
import requests
from bs4 import BeautifulSoup
import time
import numpy as np
import re

class extract_portal_wikipedia:
    
    def __init__(self, url_portal):
        self.url_portal = url_portal
        
        
    def extract_url(self):
        
        req = requests.get(self.url_portal)
        soup = BeautifulSoup(req.text, "lxml")
        
        tmp_links = []
        urls = []
        
        for i in soup.find_all(name = 'li'):
            for link in i.find_all('a', href=True):
                tmp_links.append(link['href'])
        for i in tmp_links: 
            article=re.findall( '/wiki/(.*?)$', i)
            if article!=[]:
                urls.append(article)
        return urls
    
    def extract_resumes(self,urls):
        resumes = []
        articles = []
        for url in urls:
            print(f'Récupération résumés de {url}')
            try:
                resume = wikipedia.summary(url)
                if resume != '':
                    resumes.append(resume)
                    article = wikipedia.WikipediaPage(url).content
                    articles.append(article)
            except Exception:
                print(f'Je suis INCAPABLE DE RECUPERER {url}')
                pass 
        return resumes, articles

# %%
portail_economie = extract_portal_wikipedia('https://fr.wikipedia.org/w/index.php?title=Cat%C3%A9gorie:Portail:%C3%89conomie/Articles_li%C3%A9s&from=B')
url_economie = portail_economie.extract_url()
resumes = portail_economie.extract_resumes(url_economie[0:20])
# Out:
# Récupération résumés de ['Cat%C3%A9gorie:%C3%89conomie']
# Je suis INCAPABLE DE RECUPERER ['Cat%C3%A9gorie:%C3%89conomie']
# Récupération résumés de ['Portail:%C3%89conomie']
# Je suis INCAPABLE DE RECUPERER ['Portail:%C3%89conomie']
# Récupération résumés de ['Projet:%C3%89conomie']
# Récupération résumés de ['Discussion_Projet:%C3%89conomie']
# Récupération résumés de ['Cat%C3%A9gorie:Portail:%C3%89conomie/Articles_li%C3%A9s']
# Je suis INCAPABLE DE RECUPERER ['Cat%C3%A9gorie:Portail:%C3%89conomie/Articles_li%C3%A9s']
# Récupération résumés de ['Sp%C3%A9cial:ArbreCat%C3%A9gorie/Portail:%C3%89conomie/Articles_li%C3%A9s']
# Je suis INCAPABLE DE RECUPERER ['Sp%C3%A9cial:ArbreCat%C3%A9gorie/Portail:%C3%89conomie/Articles_li%C3%A9s']
# Récupération résumés de ['Sp%C3%A9cial:Recherche/incategory:%22Portail:%C3%89conomie/Articles_li%C3%A9s%22']
# Je suis INCAPABLE DE RECUPERER ['Sp%C3%A9cial:Recherche/incategory:%22Portail:%C3%89conomie/Articles_li%C3%A9s%22']
# ...
